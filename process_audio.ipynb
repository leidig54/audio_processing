# %%
import glob
import os
import audio_process_functions as apf

# %%
client, bucket, blob_list = apf.setup_environment()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d31a6f43300e> in <module>
# ----> 1 client, bucket, blob_list = apf.setup_environment()
#
# ~/Development/misc/audio_processing/audio_process_functions.py in setup_environment()
#      26     # Get current blobs
#      27     blob_list = []
# ---> 28     for file in storage_client.list_blobs(bucket):
#      29         blob_list.append(file.name)
#      30
#
# /opt/anaconda3/lib/python3.8/site-packages/google/api_core/page_iterator.py in _items_iter(self)
#     210     def _items_iter(self):
#     211         """Iterator for each item returned."""
# --> 212         for page in self._page_iter(increment=False):
#     213             for item in page:
#     214                 self.num_results += 1
#
# /opt/anaconda3/lib/python3.8/site-packages/google/api_core/page_iterator.py in _page_iter(self, increment)
# ...

# %%
#Count number of files to process
count = 0
for filepath in glob.glob('/Users/georgeleidig/Desktop/FBS Wavs' + '/**/*.wav', recursive=True):
    count += 1
print(str(count) + " sounds to process")
# Out:
# 77 sounds to process

# %%
progress = 0

# Find mask folder
for filepath in glob.glob('/Users/georgeleidig/Desktop/FBS Wavs' + '/**/*.wav', recursive=True):

    #Fetch mask name
    mask_name = os.path.splitext(os.path.basename(filepath))[0]

    #Progress indicator
    progress += 1
    print(str(mask_name) + str(progress/count * 100) + "%")

    
    
    # apf.process_normal_mp3(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    # apf.process_normal_spectrogram(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    apf.process_notched(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    apf.process_peaked(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    # apf.process_bandstop(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
# Out:
# Cicada1.2987012987012987%
# Mask: Cicada, Algorithm: Notched, Frequency: 10000
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:336: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Cicada, Algorithm: Peaked, Frequency: 20, SF: 5471.444380294561
# Mask: Cicada, Algorithm: Peaked, Frequency: 40, SF: 2594.323102587996
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-41133ca7d2bb> in <module>
#      16     # apf.process_normal_spectrogram(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
# ...
