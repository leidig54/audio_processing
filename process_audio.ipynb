# %%
import glob
import os
import audio_process_functions as apf

# %%
client, bucket, blob_list = apf.setup_environment()
# Out:
# Environment set up in 3.4060158729553223 seconds

# %%
#Count number of files to process
count = 0
for filepath in glob.glob('/Users/georgeleidig/Desktop/FBS Wavs' + '/**/*.wav', recursive=True):
    count += 1
print(str(count) + " sounds to process")
# Out:
# 77 sounds to process

# %%
progress = 0

# Find mask folder
for filepath in glob.glob('/Users/georgeleidig/Desktop/FBS Wavs' + '/**/*.wav', recursive=True):

    #Fetch mask name
    mask_name = os.path.splitext(os.path.basename(filepath))[0]

    #Progress indicator
    progress += 1
    print(str(mask_name) + str(progress/count * 100) + "%")

    
    
    apf.process_normal_mp3(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    apf.process_normal_spectrogram(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    apf.process_notched(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
    # apf.process_peaked(bucket=bucket, mask_name=mask_name, blob_list=blob_list, filepath=filepath)
# Out:
# Shower1.2987012987012987%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Shower, Algorithm: Notched, Frequency: 20
# Mask: Shower, Algorithm: Notched, Frequency: 40
# Mask: Shower, Algorithm: Notched, Frequency: 60
# Mask: Shower, Algorithm: Notched, Frequency: 80
# Mask: Shower, Algorithm: Notched, Frequency: 100
# Mask: Shower, Algorithm: Notched, Frequency: 120
# Mask: Shower, Algorithm: Notched, Frequency: 140
# Mask: Shower, Algorithm: Notched, Frequency: 160
# Mask: Shower, Algorithm: Notched, Frequency: 180
# Mask: Shower, Algorithm: Notched, Frequency: 200
# Mask: Shower, Algorithm: Notched, Frequency: 300
# Mask: Shower, Algorithm: Notched, Frequency: 400
# Mask: Shower, Algorithm: Notched, Frequency: 500
# Mask: Shower, Algorithm: Notched, Frequency: 600
# Mask: Shower, Algorithm: Notched, Frequency: 700
# Mask: Shower, Algorithm: Notched, Frequency: 800
# Mask: Shower, Algorithm: Notched, Frequency: 900
# Mask: Shower, Algorithm: Notched, Frequency: 1000
# Mask: Shower, Algorithm: Notched, Frequency: 2000
# Mask: Shower, Algorithm: Notched, Frequency: 3000
# Mask: Shower, Algorithm: Notched, Frequency: 4000
# Mask: Shower, Algorithm: Notched, Frequency: 5000
# Mask: Shower, Algorithm: Notched, Frequency: 6000
# Mask: Shower, Algorithm: Notched, Frequency: 7000
# Mask: Shower, Algorithm: Notched, Frequency: 8000
# Mask: Shower, Algorithm: Notched, Frequency: 9000
# Mask: Shower, Algorithm: Notched, Frequency: 10000
# Mask: Shower, Algorithm: Notched, Frequency: 11000
# Mask: Shower, Algorithm: Notched, Frequency: 12000
# Mask: Shower, Algorithm: Notched, Frequency: 13000
# Mask: Shower, Algorithm: Notched, Frequency: 14000
# Mask: Shower, Algorithm: Notched, Frequency: 15000
# Mask: Shower, Algorithm: Notched, Frequency: 16000
# Mask: Shower, Algorithm: Notched, Frequency: 17000
# Pink2.5974025974025974%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Pink, Algorithm: Notched, Frequency: 20
# Mask: Pink, Algorithm: Notched, Frequency: 40
# Mask: Pink, Algorithm: Notched, Frequency: 60
# Mask: Pink, Algorithm: Notched, Frequency: 80
# Mask: Pink, Algorithm: Notched, Frequency: 100
# Mask: Pink, Algorithm: Notched, Frequency: 120
# Mask: Pink, Algorithm: Notched, Frequency: 140
# Mask: Pink, Algorithm: Notched, Frequency: 160
# Mask: Pink, Algorithm: Notched, Frequency: 180
# Mask: Pink, Algorithm: Notched, Frequency: 200
# Mask: Pink, Algorithm: Notched, Frequency: 300
# Mask: Pink, Algorithm: Notched, Frequency: 400
# Mask: Pink, Algorithm: Notched, Frequency: 500
# Mask: Pink, Algorithm: Notched, Frequency: 600
# Mask: Pink, Algorithm: Notched, Frequency: 700
# Mask: Pink, Algorithm: Notched, Frequency: 800
# Mask: Pink, Algorithm: Notched, Frequency: 900
# Mask: Pink, Algorithm: Notched, Frequency: 1000
# Mask: Pink, Algorithm: Notched, Frequency: 2000
# Mask: Pink, Algorithm: Notched, Frequency: 3000
# Mask: Pink, Algorithm: Notched, Frequency: 4000
# Mask: Pink, Algorithm: Notched, Frequency: 5000
# Mask: Pink, Algorithm: Notched, Frequency: 6000
# Mask: Pink, Algorithm: Notched, Frequency: 7000
# Mask: Pink, Algorithm: Notched, Frequency: 8000
# Mask: Pink, Algorithm: Notched, Frequency: 9000
# Mask: Pink, Algorithm: Notched, Frequency: 10000
# Mask: Pink, Algorithm: Notched, Frequency: 11000
# Mask: Pink, Algorithm: Notched, Frequency: 12000
# Mask: Pink, Algorithm: Notched, Frequency: 13000
# Mask: Pink, Algorithm: Notched, Frequency: 14000
# Mask: Pink, Algorithm: Notched, Frequency: 15000
# Mask: Pink, Algorithm: Notched, Frequency: 16000
# Mask: Pink, Algorithm: Notched, Frequency: 17000
# Blue3.896103896103896%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Blue, Algorithm: Notched, Frequency: 20
# Mask: Blue, Algorithm: Notched, Frequency: 40
# Mask: Blue, Algorithm: Notched, Frequency: 60
# Mask: Blue, Algorithm: Notched, Frequency: 80
# Mask: Blue, Algorithm: Notched, Frequency: 100
# Mask: Blue, Algorithm: Notched, Frequency: 120
# Mask: Blue, Algorithm: Notched, Frequency: 140
# Mask: Blue, Algorithm: Notched, Frequency: 160
# Mask: Blue, Algorithm: Notched, Frequency: 180
# Mask: Blue, Algorithm: Notched, Frequency: 200
# Mask: Blue, Algorithm: Notched, Frequency: 300
# Mask: Blue, Algorithm: Notched, Frequency: 400
# Mask: Blue, Algorithm: Notched, Frequency: 500
# Mask: Blue, Algorithm: Notched, Frequency: 600
# Mask: Blue, Algorithm: Notched, Frequency: 700
# Mask: Blue, Algorithm: Notched, Frequency: 800
# Mask: Blue, Algorithm: Notched, Frequency: 900
# Mask: Blue, Algorithm: Notched, Frequency: 1000
# Mask: Blue, Algorithm: Notched, Frequency: 2000
# Mask: Blue, Algorithm: Notched, Frequency: 3000
# Mask: Blue, Algorithm: Notched, Frequency: 4000
# Mask: Blue, Algorithm: Notched, Frequency: 5000
# Mask: Blue, Algorithm: Notched, Frequency: 6000
# Mask: Blue, Algorithm: Notched, Frequency: 7000
# Mask: Blue, Algorithm: Notched, Frequency: 8000
# Mask: Blue, Algorithm: Notched, Frequency: 9000
# Mask: Blue, Algorithm: Notched, Frequency: 10000
# Mask: Blue, Algorithm: Notched, Frequency: 11000
# Mask: Blue, Algorithm: Notched, Frequency: 12000
# Mask: Blue, Algorithm: Notched, Frequency: 13000
# Mask: Blue, Algorithm: Notched, Frequency: 14000
# Mask: Blue, Algorithm: Notched, Frequency: 15000
# Mask: Blue, Algorithm: Notched, Frequency: 16000
# Mask: Blue, Algorithm: Notched, Frequency: 17000
# Bike5.194805194805195%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Bike, Algorithm: Notched, Frequency: 20
# Mask: Bike, Algorithm: Notched, Frequency: 40
# Mask: Bike, Algorithm: Notched, Frequency: 60
# Mask: Bike, Algorithm: Notched, Frequency: 80
# Mask: Bike, Algorithm: Notched, Frequency: 100
# Mask: Bike, Algorithm: Notched, Frequency: 120
# Mask: Bike, Algorithm: Notched, Frequency: 140
# Mask: Bike, Algorithm: Notched, Frequency: 160
# Mask: Bike, Algorithm: Notched, Frequency: 180
# Mask: Bike, Algorithm: Notched, Frequency: 200
# Mask: Bike, Algorithm: Notched, Frequency: 300
# Mask: Bike, Algorithm: Notched, Frequency: 400
# Mask: Bike, Algorithm: Notched, Frequency: 500
# Mask: Bike, Algorithm: Notched, Frequency: 600
# Mask: Bike, Algorithm: Notched, Frequency: 700
# Mask: Bike, Algorithm: Notched, Frequency: 800
# Mask: Bike, Algorithm: Notched, Frequency: 900
# Mask: Bike, Algorithm: Notched, Frequency: 1000
# Mask: Bike, Algorithm: Notched, Frequency: 2000
# Mask: Bike, Algorithm: Notched, Frequency: 3000
# Mask: Bike, Algorithm: Notched, Frequency: 4000
# Mask: Bike, Algorithm: Notched, Frequency: 5000
# Mask: Bike, Algorithm: Notched, Frequency: 6000
# Mask: Bike, Algorithm: Notched, Frequency: 7000
# Mask: Bike, Algorithm: Notched, Frequency: 8000
# Mask: Bike, Algorithm: Notched, Frequency: 9000
# Mask: Bike, Algorithm: Notched, Frequency: 10000
# Mask: Bike, Algorithm: Notched, Frequency: 11000
# Mask: Bike, Algorithm: Notched, Frequency: 12000
# Mask: Bike, Algorithm: Notched, Frequency: 13000
# Mask: Bike, Algorithm: Notched, Frequency: 14000
# Mask: Bike, Algorithm: Notched, Frequency: 15000
# Mask: Bike, Algorithm: Notched, Frequency: 16000
# Mask: Bike, Algorithm: Notched, Frequency: 17000
# Alpha6.493506493506493%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Alpha, Algorithm: Notched, Frequency: 20
# Mask: Alpha, Algorithm: Notched, Frequency: 40
# Mask: Alpha, Algorithm: Notched, Frequency: 60
# Mask: Alpha, Algorithm: Notched, Frequency: 80
# Mask: Alpha, Algorithm: Notched, Frequency: 100
# Mask: Alpha, Algorithm: Notched, Frequency: 120
# Mask: Alpha, Algorithm: Notched, Frequency: 140
# Mask: Alpha, Algorithm: Notched, Frequency: 160
# Mask: Alpha, Algorithm: Notched, Frequency: 180
# Mask: Alpha, Algorithm: Notched, Frequency: 200
# Mask: Alpha, Algorithm: Notched, Frequency: 300
# Mask: Alpha, Algorithm: Notched, Frequency: 400
# Mask: Alpha, Algorithm: Notched, Frequency: 500
# Mask: Alpha, Algorithm: Notched, Frequency: 600
# Mask: Alpha, Algorithm: Notched, Frequency: 700
# Mask: Alpha, Algorithm: Notched, Frequency: 800
# Mask: Alpha, Algorithm: Notched, Frequency: 900
# Mask: Alpha, Algorithm: Notched, Frequency: 1000
# Mask: Alpha, Algorithm: Notched, Frequency: 2000
# Mask: Alpha, Algorithm: Notched, Frequency: 3000
# Mask: Alpha, Algorithm: Notched, Frequency: 4000
# Mask: Alpha, Algorithm: Notched, Frequency: 5000
# Mask: Alpha, Algorithm: Notched, Frequency: 6000
# Mask: Alpha, Algorithm: Notched, Frequency: 7000
# Mask: Alpha, Algorithm: Notched, Frequency: 8000
# Mask: Alpha, Algorithm: Notched, Frequency: 9000
# Mask: Alpha, Algorithm: Notched, Frequency: 10000
# Mask: Alpha, Algorithm: Notched, Frequency: 11000
# Mask: Alpha, Algorithm: Notched, Frequency: 12000
# Mask: Alpha, Algorithm: Notched, Frequency: 13000
# Mask: Alpha, Algorithm: Notched, Frequency: 14000
# Mask: Alpha, Algorithm: Notched, Frequency: 15000
# Mask: Alpha, Algorithm: Notched, Frequency: 16000
# Mask: Alpha, Algorithm: Notched, Frequency: 17000
# Ambience7.792207792207792%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Ambience, Algorithm: Notched, Frequency: 20
# Mask: Ambience, Algorithm: Notched, Frequency: 40
# Mask: Ambience, Algorithm: Notched, Frequency: 60
# Mask: Ambience, Algorithm: Notched, Frequency: 80
# Mask: Ambience, Algorithm: Notched, Frequency: 100
# Mask: Ambience, Algorithm: Notched, Frequency: 120
# Mask: Ambience, Algorithm: Notched, Frequency: 140
# Mask: Ambience, Algorithm: Notched, Frequency: 160
# Mask: Ambience, Algorithm: Notched, Frequency: 180
# Mask: Ambience, Algorithm: Notched, Frequency: 200
# Mask: Ambience, Algorithm: Notched, Frequency: 300
# Mask: Ambience, Algorithm: Notched, Frequency: 400
# Mask: Ambience, Algorithm: Notched, Frequency: 500
# Mask: Ambience, Algorithm: Notched, Frequency: 600
# Mask: Ambience, Algorithm: Notched, Frequency: 700
# Mask: Ambience, Algorithm: Notched, Frequency: 800
# Mask: Ambience, Algorithm: Notched, Frequency: 900
# Mask: Ambience, Algorithm: Notched, Frequency: 1000
# Mask: Ambience, Algorithm: Notched, Frequency: 2000
# Mask: Ambience, Algorithm: Notched, Frequency: 3000
# Mask: Ambience, Algorithm: Notched, Frequency: 4000
# Mask: Ambience, Algorithm: Notched, Frequency: 5000
# Mask: Ambience, Algorithm: Notched, Frequency: 6000
# Mask: Ambience, Algorithm: Notched, Frequency: 7000
# Mask: Ambience, Algorithm: Notched, Frequency: 8000
# Mask: Ambience, Algorithm: Notched, Frequency: 9000
# Mask: Ambience, Algorithm: Notched, Frequency: 10000
# Mask: Ambience, Algorithm: Notched, Frequency: 11000
# Mask: Ambience, Algorithm: Notched, Frequency: 12000
# Mask: Ambience, Algorithm: Notched, Frequency: 13000
# Mask: Ambience, Algorithm: Notched, Frequency: 14000
# Mask: Ambience, Algorithm: Notched, Frequency: 15000
# Mask: Ambience, Algorithm: Notched, Frequency: 16000
# Mask: Ambience, Algorithm: Notched, Frequency: 17000
# City9.090909090909092%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: City, Algorithm: Notched, Frequency: 20
# Mask: City, Algorithm: Notched, Frequency: 40
# Mask: City, Algorithm: Notched, Frequency: 60
# Mask: City, Algorithm: Notched, Frequency: 80
# Mask: City, Algorithm: Notched, Frequency: 100
# Mask: City, Algorithm: Notched, Frequency: 120
# Mask: City, Algorithm: Notched, Frequency: 140
# Mask: City, Algorithm: Notched, Frequency: 160
# Mask: City, Algorithm: Notched, Frequency: 180
# Mask: City, Algorithm: Notched, Frequency: 200
# Mask: City, Algorithm: Notched, Frequency: 300
# Mask: City, Algorithm: Notched, Frequency: 400
# Mask: City, Algorithm: Notched, Frequency: 500
# Mask: City, Algorithm: Notched, Frequency: 600
# Mask: City, Algorithm: Notched, Frequency: 700
# Mask: City, Algorithm: Notched, Frequency: 800
# Mask: City, Algorithm: Notched, Frequency: 900
# Mask: City, Algorithm: Notched, Frequency: 1000
# Mask: City, Algorithm: Notched, Frequency: 2000
# Mask: City, Algorithm: Notched, Frequency: 3000
# Mask: City, Algorithm: Notched, Frequency: 4000
# Mask: City, Algorithm: Notched, Frequency: 5000
# Mask: City, Algorithm: Notched, Frequency: 6000
# Mask: City, Algorithm: Notched, Frequency: 7000
# Mask: City, Algorithm: Notched, Frequency: 8000
# Mask: City, Algorithm: Notched, Frequency: 9000
# Mask: City, Algorithm: Notched, Frequency: 10000
# Mask: City, Algorithm: Notched, Frequency: 11000
# Mask: City, Algorithm: Notched, Frequency: 12000
# Mask: City, Algorithm: Notched, Frequency: 13000
# Mask: City, Algorithm: Notched, Frequency: 14000
# Mask: City, Algorithm: Notched, Frequency: 15000
# Mask: City, Algorithm: Notched, Frequency: 16000
# Mask: City, Algorithm: Notched, Frequency: 17000
# Bee10.38961038961039%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Bee, Algorithm: Notched, Frequency: 20
# Mask: Bee, Algorithm: Notched, Frequency: 40
# Mask: Bee, Algorithm: Notched, Frequency: 60
# Mask: Bee, Algorithm: Notched, Frequency: 80
# Mask: Bee, Algorithm: Notched, Frequency: 100
# Mask: Bee, Algorithm: Notched, Frequency: 120
# Mask: Bee, Algorithm: Notched, Frequency: 140
# Mask: Bee, Algorithm: Notched, Frequency: 160
# Mask: Bee, Algorithm: Notched, Frequency: 180
# Mask: Bee, Algorithm: Notched, Frequency: 200
# Mask: Bee, Algorithm: Notched, Frequency: 300
# Mask: Bee, Algorithm: Notched, Frequency: 400
# Mask: Bee, Algorithm: Notched, Frequency: 500
# Mask: Bee, Algorithm: Notched, Frequency: 600
# Mask: Bee, Algorithm: Notched, Frequency: 700
# Mask: Bee, Algorithm: Notched, Frequency: 800
# Mask: Bee, Algorithm: Notched, Frequency: 900
# Mask: Bee, Algorithm: Notched, Frequency: 1000
# Mask: Bee, Algorithm: Notched, Frequency: 2000
# Mask: Bee, Algorithm: Notched, Frequency: 3000
# Mask: Bee, Algorithm: Notched, Frequency: 4000
# Mask: Bee, Algorithm: Notched, Frequency: 5000
# Mask: Bee, Algorithm: Notched, Frequency: 6000
# Mask: Bee, Algorithm: Notched, Frequency: 7000
# Mask: Bee, Algorithm: Notched, Frequency: 8000
# Mask: Bee, Algorithm: Notched, Frequency: 9000
# Mask: Bee, Algorithm: Notched, Frequency: 10000
# Mask: Bee, Algorithm: Notched, Frequency: 11000
# Mask: Bee, Algorithm: Notched, Frequency: 12000
# Mask: Bee, Algorithm: Notched, Frequency: 13000
# Mask: Bee, Algorithm: Notched, Frequency: 14000
# Mask: Bee, Algorithm: Notched, Frequency: 15000
# Mask: Bee, Algorithm: Notched, Frequency: 16000
# Mask: Bee, Algorithm: Notched, Frequency: 17000
# Theta11.688311688311687%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Theta, Algorithm: Notched, Frequency: 20
# Mask: Theta, Algorithm: Notched, Frequency: 40
# Mask: Theta, Algorithm: Notched, Frequency: 60
# Mask: Theta, Algorithm: Notched, Frequency: 80
# Mask: Theta, Algorithm: Notched, Frequency: 100
# Mask: Theta, Algorithm: Notched, Frequency: 120
# Mask: Theta, Algorithm: Notched, Frequency: 140
# Mask: Theta, Algorithm: Notched, Frequency: 160
# Mask: Theta, Algorithm: Notched, Frequency: 180
# Mask: Theta, Algorithm: Notched, Frequency: 200
# Mask: Theta, Algorithm: Notched, Frequency: 300
# Mask: Theta, Algorithm: Notched, Frequency: 400
# Mask: Theta, Algorithm: Notched, Frequency: 500
# Mask: Theta, Algorithm: Notched, Frequency: 600
# Mask: Theta, Algorithm: Notched, Frequency: 700
# Mask: Theta, Algorithm: Notched, Frequency: 800
# Mask: Theta, Algorithm: Notched, Frequency: 900
# Mask: Theta, Algorithm: Notched, Frequency: 1000
# Mask: Theta, Algorithm: Notched, Frequency: 2000
# Mask: Theta, Algorithm: Notched, Frequency: 3000
# Mask: Theta, Algorithm: Notched, Frequency: 4000
# Mask: Theta, Algorithm: Notched, Frequency: 5000
# Mask: Theta, Algorithm: Notched, Frequency: 6000
# Mask: Theta, Algorithm: Notched, Frequency: 7000
# Mask: Theta, Algorithm: Notched, Frequency: 8000
# Mask: Theta, Algorithm: Notched, Frequency: 9000
# Mask: Theta, Algorithm: Notched, Frequency: 10000
# Mask: Theta, Algorithm: Notched, Frequency: 11000
# Mask: Theta, Algorithm: Notched, Frequency: 12000
# Mask: Theta, Algorithm: Notched, Frequency: 13000
# Mask: Theta, Algorithm: Notched, Frequency: 14000
# Mask: Theta, Algorithm: Notched, Frequency: 15000
# Mask: Theta, Algorithm: Notched, Frequency: 16000
# Mask: Theta, Algorithm: Notched, Frequency: 17000
# Pad12.987012987012985%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Pad, Algorithm: Notched, Frequency: 20
# Mask: Pad, Algorithm: Notched, Frequency: 40
# Mask: Pad, Algorithm: Notched, Frequency: 60
# Mask: Pad, Algorithm: Notched, Frequency: 80
# Mask: Pad, Algorithm: Notched, Frequency: 100
# Mask: Pad, Algorithm: Notched, Frequency: 120
# Mask: Pad, Algorithm: Notched, Frequency: 140
# Mask: Pad, Algorithm: Notched, Frequency: 160
# Mask: Pad, Algorithm: Notched, Frequency: 180
# Mask: Pad, Algorithm: Notched, Frequency: 200
# Mask: Pad, Algorithm: Notched, Frequency: 300
# Mask: Pad, Algorithm: Notched, Frequency: 400
# Mask: Pad, Algorithm: Notched, Frequency: 500
# Mask: Pad, Algorithm: Notched, Frequency: 600
# Mask: Pad, Algorithm: Notched, Frequency: 700
# Mask: Pad, Algorithm: Notched, Frequency: 800
# Mask: Pad, Algorithm: Notched, Frequency: 900
# Mask: Pad, Algorithm: Notched, Frequency: 1000
# Mask: Pad, Algorithm: Notched, Frequency: 2000
# Mask: Pad, Algorithm: Notched, Frequency: 3000
# Mask: Pad, Algorithm: Notched, Frequency: 4000
# Mask: Pad, Algorithm: Notched, Frequency: 5000
# Mask: Pad, Algorithm: Notched, Frequency: 6000
# Mask: Pad, Algorithm: Notched, Frequency: 7000
# Mask: Pad, Algorithm: Notched, Frequency: 8000
# Mask: Pad, Algorithm: Notched, Frequency: 9000
# Mask: Pad, Algorithm: Notched, Frequency: 10000
# Mask: Pad, Algorithm: Notched, Frequency: 11000
# Mask: Pad, Algorithm: Notched, Frequency: 12000
# Mask: Pad, Algorithm: Notched, Frequency: 13000
# Mask: Pad, Algorithm: Notched, Frequency: 14000
# Mask: Pad, Algorithm: Notched, Frequency: 15000
# Mask: Pad, Algorithm: Notched, Frequency: 16000
# Mask: Pad, Algorithm: Notched, Frequency: 17000
# Boiling14.285714285714285%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Boiling, Algorithm: Notched, Frequency: 20
# Mask: Boiling, Algorithm: Notched, Frequency: 40
# Mask: Boiling, Algorithm: Notched, Frequency: 60
# Mask: Boiling, Algorithm: Notched, Frequency: 80
# Mask: Boiling, Algorithm: Notched, Frequency: 100
# Mask: Boiling, Algorithm: Notched, Frequency: 120
# Mask: Boiling, Algorithm: Notched, Frequency: 140
# Mask: Boiling, Algorithm: Notched, Frequency: 160
# Mask: Boiling, Algorithm: Notched, Frequency: 180
# Mask: Boiling, Algorithm: Notched, Frequency: 200
# Mask: Boiling, Algorithm: Notched, Frequency: 300
# Mask: Boiling, Algorithm: Notched, Frequency: 400
# Mask: Boiling, Algorithm: Notched, Frequency: 500
# Mask: Boiling, Algorithm: Notched, Frequency: 600
# Mask: Boiling, Algorithm: Notched, Frequency: 700
# Mask: Boiling, Algorithm: Notched, Frequency: 800
# Mask: Boiling, Algorithm: Notched, Frequency: 900
# Mask: Boiling, Algorithm: Notched, Frequency: 1000
# Mask: Boiling, Algorithm: Notched, Frequency: 2000
# Mask: Boiling, Algorithm: Notched, Frequency: 3000
# Mask: Boiling, Algorithm: Notched, Frequency: 4000
# Mask: Boiling, Algorithm: Notched, Frequency: 5000
# Mask: Boiling, Algorithm: Notched, Frequency: 6000
# Mask: Boiling, Algorithm: Notched, Frequency: 7000
# Mask: Boiling, Algorithm: Notched, Frequency: 8000
# Mask: Boiling, Algorithm: Notched, Frequency: 9000
# Mask: Boiling, Algorithm: Notched, Frequency: 10000
# Mask: Boiling, Algorithm: Notched, Frequency: 11000
# Mask: Boiling, Algorithm: Notched, Frequency: 12000
# Mask: Boiling, Algorithm: Notched, Frequency: 13000
# Mask: Boiling, Algorithm: Notched, Frequency: 14000
# Mask: Boiling, Algorithm: Notched, Frequency: 15000
# Mask: Boiling, Algorithm: Notched, Frequency: 16000
# Mask: Boiling, Algorithm: Notched, Frequency: 17000
# Cobblestone15.584415584415584%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Cobblestone, Algorithm: Notched, Frequency: 20
# Mask: Cobblestone, Algorithm: Notched, Frequency: 40
# Mask: Cobblestone, Algorithm: Notched, Frequency: 60
# Mask: Cobblestone, Algorithm: Notched, Frequency: 80
# Mask: Cobblestone, Algorithm: Notched, Frequency: 100
# Mask: Cobblestone, Algorithm: Notched, Frequency: 120
# Mask: Cobblestone, Algorithm: Notched, Frequency: 140
# Mask: Cobblestone, Algorithm: Notched, Frequency: 160
# Mask: Cobblestone, Algorithm: Notched, Frequency: 180
# Mask: Cobblestone, Algorithm: Notched, Frequency: 200
# Mask: Cobblestone, Algorithm: Notched, Frequency: 300
# Mask: Cobblestone, Algorithm: Notched, Frequency: 400
# Mask: Cobblestone, Algorithm: Notched, Frequency: 500
# Mask: Cobblestone, Algorithm: Notched, Frequency: 600
# Mask: Cobblestone, Algorithm: Notched, Frequency: 700
# Mask: Cobblestone, Algorithm: Notched, Frequency: 800
# Mask: Cobblestone, Algorithm: Notched, Frequency: 900
# Mask: Cobblestone, Algorithm: Notched, Frequency: 1000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 2000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 3000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 4000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 5000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 6000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 7000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 8000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 9000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 10000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 11000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 12000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 13000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 14000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 15000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 16000
# Mask: Cobblestone, Algorithm: Notched, Frequency: 17000
# Frost16.883116883116884%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Frost, Algorithm: Notched, Frequency: 20
# Mask: Frost, Algorithm: Notched, Frequency: 40
# Mask: Frost, Algorithm: Notched, Frequency: 60
# Mask: Frost, Algorithm: Notched, Frequency: 80
# Mask: Frost, Algorithm: Notched, Frequency: 100
# Mask: Frost, Algorithm: Notched, Frequency: 120
# Mask: Frost, Algorithm: Notched, Frequency: 140
# Mask: Frost, Algorithm: Notched, Frequency: 160
# Mask: Frost, Algorithm: Notched, Frequency: 180
# Mask: Frost, Algorithm: Notched, Frequency: 200
# Mask: Frost, Algorithm: Notched, Frequency: 300
# Mask: Frost, Algorithm: Notched, Frequency: 400
# Mask: Frost, Algorithm: Notched, Frequency: 500
# Mask: Frost, Algorithm: Notched, Frequency: 600
# Mask: Frost, Algorithm: Notched, Frequency: 700
# Mask: Frost, Algorithm: Notched, Frequency: 800
# Mask: Frost, Algorithm: Notched, Frequency: 900
# Mask: Frost, Algorithm: Notched, Frequency: 1000
# Mask: Frost, Algorithm: Notched, Frequency: 2000
# Mask: Frost, Algorithm: Notched, Frequency: 3000
# Mask: Frost, Algorithm: Notched, Frequency: 4000
# Mask: Frost, Algorithm: Notched, Frequency: 5000
# Mask: Frost, Algorithm: Notched, Frequency: 6000
# Mask: Frost, Algorithm: Notched, Frequency: 7000
# Mask: Frost, Algorithm: Notched, Frequency: 8000
# Mask: Frost, Algorithm: Notched, Frequency: 9000
# Mask: Frost, Algorithm: Notched, Frequency: 10000
# Mask: Frost, Algorithm: Notched, Frequency: 11000
# Mask: Frost, Algorithm: Notched, Frequency: 12000
# Mask: Frost, Algorithm: Notched, Frequency: 13000
# Mask: Frost, Algorithm: Notched, Frequency: 14000
# Mask: Frost, Algorithm: Notched, Frequency: 15000
# Mask: Frost, Algorithm: Notched, Frequency: 16000
# Mask: Frost, Algorithm: Notched, Frequency: 17000
# Hoover18.181818181818183%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Hoover, Algorithm: Notched, Frequency: 20
# Mask: Hoover, Algorithm: Notched, Frequency: 40
# Mask: Hoover, Algorithm: Notched, Frequency: 60
# Mask: Hoover, Algorithm: Notched, Frequency: 80
# Mask: Hoover, Algorithm: Notched, Frequency: 100
# Mask: Hoover, Algorithm: Notched, Frequency: 120
# Mask: Hoover, Algorithm: Notched, Frequency: 140
# Mask: Hoover, Algorithm: Notched, Frequency: 160
# Mask: Hoover, Algorithm: Notched, Frequency: 180
# Mask: Hoover, Algorithm: Notched, Frequency: 200
# Mask: Hoover, Algorithm: Notched, Frequency: 300
# Mask: Hoover, Algorithm: Notched, Frequency: 400
# Mask: Hoover, Algorithm: Notched, Frequency: 500
# Mask: Hoover, Algorithm: Notched, Frequency: 600
# Mask: Hoover, Algorithm: Notched, Frequency: 700
# Mask: Hoover, Algorithm: Notched, Frequency: 800
# Mask: Hoover, Algorithm: Notched, Frequency: 900
# Mask: Hoover, Algorithm: Notched, Frequency: 1000
# Mask: Hoover, Algorithm: Notched, Frequency: 2000
# Mask: Hoover, Algorithm: Notched, Frequency: 3000
# Mask: Hoover, Algorithm: Notched, Frequency: 4000
# Mask: Hoover, Algorithm: Notched, Frequency: 5000
# Mask: Hoover, Algorithm: Notched, Frequency: 6000
# Mask: Hoover, Algorithm: Notched, Frequency: 7000
# Mask: Hoover, Algorithm: Notched, Frequency: 8000
# Mask: Hoover, Algorithm: Notched, Frequency: 9000
# Mask: Hoover, Algorithm: Notched, Frequency: 10000
# Mask: Hoover, Algorithm: Notched, Frequency: 11000
# Mask: Hoover, Algorithm: Notched, Frequency: 12000
# Mask: Hoover, Algorithm: Notched, Frequency: 13000
# Mask: Hoover, Algorithm: Notched, Frequency: 14000
# Mask: Hoover, Algorithm: Notched, Frequency: 15000
# Mask: Hoover, Algorithm: Notched, Frequency: 16000
# Mask: Hoover, Algorithm: Notched, Frequency: 17000
# Extractor19.480519480519483%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Extractor, Algorithm: Notched, Frequency: 20
# Mask: Extractor, Algorithm: Notched, Frequency: 40
# Mask: Extractor, Algorithm: Notched, Frequency: 60
# Mask: Extractor, Algorithm: Notched, Frequency: 80
# Mask: Extractor, Algorithm: Notched, Frequency: 100
# Mask: Extractor, Algorithm: Notched, Frequency: 120
# Mask: Extractor, Algorithm: Notched, Frequency: 140
# Mask: Extractor, Algorithm: Notched, Frequency: 160
# Mask: Extractor, Algorithm: Notched, Frequency: 180
# Mask: Extractor, Algorithm: Notched, Frequency: 200
# Mask: Extractor, Algorithm: Notched, Frequency: 300
# Mask: Extractor, Algorithm: Notched, Frequency: 400
# Mask: Extractor, Algorithm: Notched, Frequency: 500
# Mask: Extractor, Algorithm: Notched, Frequency: 600
# Mask: Extractor, Algorithm: Notched, Frequency: 700
# Mask: Extractor, Algorithm: Notched, Frequency: 800
# Mask: Extractor, Algorithm: Notched, Frequency: 900
# Mask: Extractor, Algorithm: Notched, Frequency: 1000
# Mask: Extractor, Algorithm: Notched, Frequency: 2000
# Mask: Extractor, Algorithm: Notched, Frequency: 3000
# Mask: Extractor, Algorithm: Notched, Frequency: 4000
# Mask: Extractor, Algorithm: Notched, Frequency: 5000
# Mask: Extractor, Algorithm: Notched, Frequency: 6000
# Mask: Extractor, Algorithm: Notched, Frequency: 7000
# Mask: Extractor, Algorithm: Notched, Frequency: 8000
# Mask: Extractor, Algorithm: Notched, Frequency: 9000
# Mask: Extractor, Algorithm: Notched, Frequency: 10000
# Mask: Extractor, Algorithm: Notched, Frequency: 11000
# Mask: Extractor, Algorithm: Notched, Frequency: 12000
# Mask: Extractor, Algorithm: Notched, Frequency: 13000
# Mask: Extractor, Algorithm: Notched, Frequency: 14000
# Mask: Extractor, Algorithm: Notched, Frequency: 15000
# Mask: Extractor, Algorithm: Notched, Frequency: 16000
# Mask: Extractor, Algorithm: Notched, Frequency: 17000
# Boiler20.77922077922078%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Boiler, Algorithm: Notched, Frequency: 20
# Mask: Boiler, Algorithm: Notched, Frequency: 40
# Mask: Boiler, Algorithm: Notched, Frequency: 60
# Mask: Boiler, Algorithm: Notched, Frequency: 80
# Mask: Boiler, Algorithm: Notched, Frequency: 100
# Mask: Boiler, Algorithm: Notched, Frequency: 120
# Mask: Boiler, Algorithm: Notched, Frequency: 140
# Mask: Boiler, Algorithm: Notched, Frequency: 160
# Mask: Boiler, Algorithm: Notched, Frequency: 180
# Mask: Boiler, Algorithm: Notched, Frequency: 200
# Mask: Boiler, Algorithm: Notched, Frequency: 300
# Mask: Boiler, Algorithm: Notched, Frequency: 400
# Mask: Boiler, Algorithm: Notched, Frequency: 500
# Mask: Boiler, Algorithm: Notched, Frequency: 600
# Mask: Boiler, Algorithm: Notched, Frequency: 700
# Mask: Boiler, Algorithm: Notched, Frequency: 800
# Mask: Boiler, Algorithm: Notched, Frequency: 900
# Mask: Boiler, Algorithm: Notched, Frequency: 1000
# Mask: Boiler, Algorithm: Notched, Frequency: 2000
# Mask: Boiler, Algorithm: Notched, Frequency: 3000
# Mask: Boiler, Algorithm: Notched, Frequency: 4000
# Mask: Boiler, Algorithm: Notched, Frequency: 5000
# Mask: Boiler, Algorithm: Notched, Frequency: 6000
# Mask: Boiler, Algorithm: Notched, Frequency: 7000
# Mask: Boiler, Algorithm: Notched, Frequency: 8000
# Mask: Boiler, Algorithm: Notched, Frequency: 9000
# Mask: Boiler, Algorithm: Notched, Frequency: 10000
# Mask: Boiler, Algorithm: Notched, Frequency: 11000
# Mask: Boiler, Algorithm: Notched, Frequency: 12000
# Mask: Boiler, Algorithm: Notched, Frequency: 13000
# Mask: Boiler, Algorithm: Notched, Frequency: 14000
# Mask: Boiler, Algorithm: Notched, Frequency: 15000
# Mask: Boiler, Algorithm: Notched, Frequency: 16000
# Mask: Boiler, Algorithm: Notched, Frequency: 17000
# Snow22.07792207792208%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Snow, Algorithm: Notched, Frequency: 20
# Mask: Snow, Algorithm: Notched, Frequency: 40
# Mask: Snow, Algorithm: Notched, Frequency: 60
# Mask: Snow, Algorithm: Notched, Frequency: 80
# Mask: Snow, Algorithm: Notched, Frequency: 100
# Mask: Snow, Algorithm: Notched, Frequency: 120
# Mask: Snow, Algorithm: Notched, Frequency: 140
# Mask: Snow, Algorithm: Notched, Frequency: 160
# Mask: Snow, Algorithm: Notched, Frequency: 180
# Mask: Snow, Algorithm: Notched, Frequency: 200
# Mask: Snow, Algorithm: Notched, Frequency: 300
# Mask: Snow, Algorithm: Notched, Frequency: 400
# Mask: Snow, Algorithm: Notched, Frequency: 500
# Mask: Snow, Algorithm: Notched, Frequency: 600
# Mask: Snow, Algorithm: Notched, Frequency: 700
# Mask: Snow, Algorithm: Notched, Frequency: 800
# Mask: Snow, Algorithm: Notched, Frequency: 900
# Mask: Snow, Algorithm: Notched, Frequency: 1000
# Mask: Snow, Algorithm: Notched, Frequency: 2000
# Mask: Snow, Algorithm: Notched, Frequency: 3000
# Mask: Snow, Algorithm: Notched, Frequency: 4000
# Mask: Snow, Algorithm: Notched, Frequency: 5000
# Mask: Snow, Algorithm: Notched, Frequency: 6000
# Mask: Snow, Algorithm: Notched, Frequency: 7000
# Mask: Snow, Algorithm: Notched, Frequency: 8000
# Mask: Snow, Algorithm: Notched, Frequency: 9000
# Mask: Snow, Algorithm: Notched, Frequency: 10000
# Mask: Snow, Algorithm: Notched, Frequency: 11000
# Mask: Snow, Algorithm: Notched, Frequency: 12000
# Mask: Snow, Algorithm: Notched, Frequency: 13000
# Mask: Snow, Algorithm: Notched, Frequency: 14000
# Mask: Snow, Algorithm: Notched, Frequency: 15000
# Mask: Snow, Algorithm: Notched, Frequency: 16000
# Mask: Snow, Algorithm: Notched, Frequency: 17000
# Wood23.376623376623375%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Wood, Algorithm: Notched, Frequency: 20
# Mask: Wood, Algorithm: Notched, Frequency: 40
# Mask: Wood, Algorithm: Notched, Frequency: 60
# Mask: Wood, Algorithm: Notched, Frequency: 80
# Mask: Wood, Algorithm: Notched, Frequency: 100
# Mask: Wood, Algorithm: Notched, Frequency: 120
# Mask: Wood, Algorithm: Notched, Frequency: 140
# Mask: Wood, Algorithm: Notched, Frequency: 160
# Mask: Wood, Algorithm: Notched, Frequency: 180
# Mask: Wood, Algorithm: Notched, Frequency: 200
# Mask: Wood, Algorithm: Notched, Frequency: 300
# Mask: Wood, Algorithm: Notched, Frequency: 400
# Mask: Wood, Algorithm: Notched, Frequency: 500
# Mask: Wood, Algorithm: Notched, Frequency: 600
# Mask: Wood, Algorithm: Notched, Frequency: 700
# Mask: Wood, Algorithm: Notched, Frequency: 800
# Mask: Wood, Algorithm: Notched, Frequency: 900
# Mask: Wood, Algorithm: Notched, Frequency: 1000
# Mask: Wood, Algorithm: Notched, Frequency: 2000
# Mask: Wood, Algorithm: Notched, Frequency: 3000
# Mask: Wood, Algorithm: Notched, Frequency: 4000
# Mask: Wood, Algorithm: Notched, Frequency: 5000
# Mask: Wood, Algorithm: Notched, Frequency: 6000
# Mask: Wood, Algorithm: Notched, Frequency: 7000
# Mask: Wood, Algorithm: Notched, Frequency: 8000
# Mask: Wood, Algorithm: Notched, Frequency: 9000
# Mask: Wood, Algorithm: Notched, Frequency: 10000
# Mask: Wood, Algorithm: Notched, Frequency: 11000
# Mask: Wood, Algorithm: Notched, Frequency: 12000
# Mask: Wood, Algorithm: Notched, Frequency: 13000
# Mask: Wood, Algorithm: Notched, Frequency: 14000
# Mask: Wood, Algorithm: Notched, Frequency: 15000
# Mask: Wood, Algorithm: Notched, Frequency: 16000
# Mask: Wood, Algorithm: Notched, Frequency: 17000
# Jetski24.675324675324674%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Jetski, Algorithm: Notched, Frequency: 20
# Mask: Jetski, Algorithm: Notched, Frequency: 40
# Mask: Jetski, Algorithm: Notched, Frequency: 60
# Mask: Jetski, Algorithm: Notched, Frequency: 80
# Mask: Jetski, Algorithm: Notched, Frequency: 100
# Mask: Jetski, Algorithm: Notched, Frequency: 120
# Mask: Jetski, Algorithm: Notched, Frequency: 140
# Mask: Jetski, Algorithm: Notched, Frequency: 160
# Mask: Jetski, Algorithm: Notched, Frequency: 180
# Mask: Jetski, Algorithm: Notched, Frequency: 200
# Mask: Jetski, Algorithm: Notched, Frequency: 300
# Mask: Jetski, Algorithm: Notched, Frequency: 400
# Mask: Jetski, Algorithm: Notched, Frequency: 500
# Mask: Jetski, Algorithm: Notched, Frequency: 600
# Mask: Jetski, Algorithm: Notched, Frequency: 700
# Mask: Jetski, Algorithm: Notched, Frequency: 800
# Mask: Jetski, Algorithm: Notched, Frequency: 900
# Mask: Jetski, Algorithm: Notched, Frequency: 1000
# Mask: Jetski, Algorithm: Notched, Frequency: 2000
# Mask: Jetski, Algorithm: Notched, Frequency: 3000
# Mask: Jetski, Algorithm: Notched, Frequency: 4000
# Mask: Jetski, Algorithm: Notched, Frequency: 5000
# Mask: Jetski, Algorithm: Notched, Frequency: 6000
# Mask: Jetski, Algorithm: Notched, Frequency: 7000
# Mask: Jetski, Algorithm: Notched, Frequency: 8000
# Mask: Jetski, Algorithm: Notched, Frequency: 9000
# Mask: Jetski, Algorithm: Notched, Frequency: 10000
# Mask: Jetski, Algorithm: Notched, Frequency: 11000
# Mask: Jetski, Algorithm: Notched, Frequency: 12000
# Mask: Jetski, Algorithm: Notched, Frequency: 13000
# Mask: Jetski, Algorithm: Notched, Frequency: 14000
# Mask: Jetski, Algorithm: Notched, Frequency: 15000
# Mask: Jetski, Algorithm: Notched, Frequency: 16000
# Mask: Jetski, Algorithm: Notched, Frequency: 17000
# Restaurant25.97402597402597%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Restaurant, Algorithm: Notched, Frequency: 20
# Mask: Restaurant, Algorithm: Notched, Frequency: 40
# Mask: Restaurant, Algorithm: Notched, Frequency: 60
# Mask: Restaurant, Algorithm: Notched, Frequency: 80
# Mask: Restaurant, Algorithm: Notched, Frequency: 100
# Mask: Restaurant, Algorithm: Notched, Frequency: 120
# Mask: Restaurant, Algorithm: Notched, Frequency: 140
# Mask: Restaurant, Algorithm: Notched, Frequency: 160
# Mask: Restaurant, Algorithm: Notched, Frequency: 180
# Mask: Restaurant, Algorithm: Notched, Frequency: 200
# Mask: Restaurant, Algorithm: Notched, Frequency: 300
# Mask: Restaurant, Algorithm: Notched, Frequency: 400
# Mask: Restaurant, Algorithm: Notched, Frequency: 500
# Mask: Restaurant, Algorithm: Notched, Frequency: 600
# Mask: Restaurant, Algorithm: Notched, Frequency: 700
# Mask: Restaurant, Algorithm: Notched, Frequency: 800
# Mask: Restaurant, Algorithm: Notched, Frequency: 900
# Mask: Restaurant, Algorithm: Notched, Frequency: 1000
# Mask: Restaurant, Algorithm: Notched, Frequency: 2000
# Mask: Restaurant, Algorithm: Notched, Frequency: 3000
# Mask: Restaurant, Algorithm: Notched, Frequency: 4000
# Mask: Restaurant, Algorithm: Notched, Frequency: 5000
# Mask: Restaurant, Algorithm: Notched, Frequency: 6000
# Mask: Restaurant, Algorithm: Notched, Frequency: 7000
# Mask: Restaurant, Algorithm: Notched, Frequency: 8000
# Mask: Restaurant, Algorithm: Notched, Frequency: 9000
# Mask: Restaurant, Algorithm: Notched, Frequency: 10000
# Mask: Restaurant, Algorithm: Notched, Frequency: 11000
# Mask: Restaurant, Algorithm: Notched, Frequency: 12000
# Mask: Restaurant, Algorithm: Notched, Frequency: 13000
# Mask: Restaurant, Algorithm: Notched, Frequency: 14000
# Mask: Restaurant, Algorithm: Notched, Frequency: 15000
# Mask: Restaurant, Algorithm: Notched, Frequency: 16000
# Mask: Restaurant, Algorithm: Notched, Frequency: 17000
# Casino27.27272727272727%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Casino, Algorithm: Notched, Frequency: 20
# Mask: Casino, Algorithm: Notched, Frequency: 40
# Mask: Casino, Algorithm: Notched, Frequency: 60
# Mask: Casino, Algorithm: Notched, Frequency: 80
# Mask: Casino, Algorithm: Notched, Frequency: 100
# Mask: Casino, Algorithm: Notched, Frequency: 120
# Mask: Casino, Algorithm: Notched, Frequency: 140
# Mask: Casino, Algorithm: Notched, Frequency: 160
# Mask: Casino, Algorithm: Notched, Frequency: 180
# Mask: Casino, Algorithm: Notched, Frequency: 200
# Mask: Casino, Algorithm: Notched, Frequency: 300
# Mask: Casino, Algorithm: Notched, Frequency: 400
# Mask: Casino, Algorithm: Notched, Frequency: 500
# Mask: Casino, Algorithm: Notched, Frequency: 600
# Mask: Casino, Algorithm: Notched, Frequency: 700
# Mask: Casino, Algorithm: Notched, Frequency: 800
# Mask: Casino, Algorithm: Notched, Frequency: 900
# Mask: Casino, Algorithm: Notched, Frequency: 1000
# Mask: Casino, Algorithm: Notched, Frequency: 2000
# Mask: Casino, Algorithm: Notched, Frequency: 3000
# Mask: Casino, Algorithm: Notched, Frequency: 4000
# Mask: Casino, Algorithm: Notched, Frequency: 5000
# Mask: Casino, Algorithm: Notched, Frequency: 6000
# Mask: Casino, Algorithm: Notched, Frequency: 7000
# Mask: Casino, Algorithm: Notched, Frequency: 8000
# Mask: Casino, Algorithm: Notched, Frequency: 9000
# Mask: Casino, Algorithm: Notched, Frequency: 10000
# Mask: Casino, Algorithm: Notched, Frequency: 11000
# Mask: Casino, Algorithm: Notched, Frequency: 12000
# Mask: Casino, Algorithm: Notched, Frequency: 13000
# Mask: Casino, Algorithm: Notched, Frequency: 14000
# Mask: Casino, Algorithm: Notched, Frequency: 15000
# Mask: Casino, Algorithm: Notched, Frequency: 16000
# Mask: Casino, Algorithm: Notched, Frequency: 17000
# Thunderstorm28.57142857142857%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 20
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 40
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 60
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 80
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 100
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 120
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 140
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 160
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 180
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 200
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 300
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 400
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 500
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 600
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 700
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 800
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 900
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 1000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 2000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 3000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 4000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 5000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 6000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 7000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 8000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 9000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 10000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 11000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 12000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 13000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 14000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 15000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 16000
# Mask: Thunderstorm, Algorithm: Notched, Frequency: 17000
# Book29.87012987012987%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Book, Algorithm: Notched, Frequency: 20
# Mask: Book, Algorithm: Notched, Frequency: 40
# Mask: Book, Algorithm: Notched, Frequency: 60
# Mask: Book, Algorithm: Notched, Frequency: 80
# Mask: Book, Algorithm: Notched, Frequency: 100
# Mask: Book, Algorithm: Notched, Frequency: 120
# Mask: Book, Algorithm: Notched, Frequency: 140
# Mask: Book, Algorithm: Notched, Frequency: 160
# Mask: Book, Algorithm: Notched, Frequency: 180
# Mask: Book, Algorithm: Notched, Frequency: 200
# Mask: Book, Algorithm: Notched, Frequency: 300
# Mask: Book, Algorithm: Notched, Frequency: 400
# Mask: Book, Algorithm: Notched, Frequency: 500
# Mask: Book, Algorithm: Notched, Frequency: 600
# Mask: Book, Algorithm: Notched, Frequency: 700
# Mask: Book, Algorithm: Notched, Frequency: 800
# Mask: Book, Algorithm: Notched, Frequency: 900
# Mask: Book, Algorithm: Notched, Frequency: 1000
# Mask: Book, Algorithm: Notched, Frequency: 2000
# Mask: Book, Algorithm: Notched, Frequency: 3000
# Mask: Book, Algorithm: Notched, Frequency: 4000
# Mask: Book, Algorithm: Notched, Frequency: 5000
# Mask: Book, Algorithm: Notched, Frequency: 6000
# Mask: Book, Algorithm: Notched, Frequency: 7000
# Mask: Book, Algorithm: Notched, Frequency: 8000
# Mask: Book, Algorithm: Notched, Frequency: 9000
# Mask: Book, Algorithm: Notched, Frequency: 10000
# Mask: Book, Algorithm: Notched, Frequency: 11000
# Mask: Book, Algorithm: Notched, Frequency: 12000
# Mask: Book, Algorithm: Notched, Frequency: 13000
# Mask: Book, Algorithm: Notched, Frequency: 14000
# Mask: Book, Algorithm: Notched, Frequency: 15000
# Mask: Book, Algorithm: Notched, Frequency: 16000
# Mask: Book, Algorithm: Notched, Frequency: 17000
# Piano31.16883116883117%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
# ...
# Mask: Soundscape, Algorithm: Notched, Frequency: 60
# Mask: Soundscape, Algorithm: Notched, Frequency: 80
# Mask: Soundscape, Algorithm: Notched, Frequency: 100
# Mask: Soundscape, Algorithm: Notched, Frequency: 120
# Mask: Soundscape, Algorithm: Notched, Frequency: 140
# Mask: Soundscape, Algorithm: Notched, Frequency: 160
# Mask: Soundscape, Algorithm: Notched, Frequency: 180
# Mask: Soundscape, Algorithm: Notched, Frequency: 200
# Mask: Soundscape, Algorithm: Notched, Frequency: 300
# Mask: Soundscape, Algorithm: Notched, Frequency: 400
# Mask: Soundscape, Algorithm: Notched, Frequency: 500
# Mask: Soundscape, Algorithm: Notched, Frequency: 600
# Mask: Soundscape, Algorithm: Notched, Frequency: 700
# Mask: Soundscape, Algorithm: Notched, Frequency: 800
# Mask: Soundscape, Algorithm: Notched, Frequency: 900
# Mask: Soundscape, Algorithm: Notched, Frequency: 1000
# Mask: Soundscape, Algorithm: Notched, Frequency: 2000
# Mask: Soundscape, Algorithm: Notched, Frequency: 3000
# Mask: Soundscape, Algorithm: Notched, Frequency: 4000
# Mask: Soundscape, Algorithm: Notched, Frequency: 5000
# Mask: Soundscape, Algorithm: Notched, Frequency: 6000
# Mask: Soundscape, Algorithm: Notched, Frequency: 7000
# Mask: Soundscape, Algorithm: Notched, Frequency: 8000
# Mask: Soundscape, Algorithm: Notched, Frequency: 9000
# Mask: Soundscape, Algorithm: Notched, Frequency: 10000
# Mask: Soundscape, Algorithm: Notched, Frequency: 11000
# Mask: Soundscape, Algorithm: Notched, Frequency: 12000
# Mask: Soundscape, Algorithm: Notched, Frequency: 13000
# Mask: Soundscape, Algorithm: Notched, Frequency: 14000
# Mask: Soundscape, Algorithm: Notched, Frequency: 15000
# Mask: Soundscape, Algorithm: Notched, Frequency: 16000
# Mask: Soundscape, Algorithm: Notched, Frequency: 17000
# Waves92.20779220779221%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Waves, Algorithm: Notched, Frequency: 20
# Mask: Waves, Algorithm: Notched, Frequency: 40
# Mask: Waves, Algorithm: Notched, Frequency: 60
# Mask: Waves, Algorithm: Notched, Frequency: 80
# Mask: Waves, Algorithm: Notched, Frequency: 100
# Mask: Waves, Algorithm: Notched, Frequency: 120
# Mask: Waves, Algorithm: Notched, Frequency: 140
# Mask: Waves, Algorithm: Notched, Frequency: 160
# Mask: Waves, Algorithm: Notched, Frequency: 180
# Mask: Waves, Algorithm: Notched, Frequency: 200
# Mask: Waves, Algorithm: Notched, Frequency: 300
# Mask: Waves, Algorithm: Notched, Frequency: 400
# Mask: Waves, Algorithm: Notched, Frequency: 500
# Mask: Waves, Algorithm: Notched, Frequency: 600
# Mask: Waves, Algorithm: Notched, Frequency: 700
# Mask: Waves, Algorithm: Notched, Frequency: 800
# Mask: Waves, Algorithm: Notched, Frequency: 900
# Mask: Waves, Algorithm: Notched, Frequency: 1000
# Mask: Waves, Algorithm: Notched, Frequency: 2000
# Mask: Waves, Algorithm: Notched, Frequency: 3000
# Mask: Waves, Algorithm: Notched, Frequency: 4000
# Mask: Waves, Algorithm: Notched, Frequency: 5000
# Mask: Waves, Algorithm: Notched, Frequency: 6000
# Mask: Waves, Algorithm: Notched, Frequency: 7000
# Mask: Waves, Algorithm: Notched, Frequency: 8000
# Mask: Waves, Algorithm: Notched, Frequency: 9000
# Mask: Waves, Algorithm: Notched, Frequency: 10000
# Mask: Waves, Algorithm: Notched, Frequency: 11000
# Mask: Waves, Algorithm: Notched, Frequency: 12000
# Mask: Waves, Algorithm: Notched, Frequency: 13000
# Mask: Waves, Algorithm: Notched, Frequency: 14000
# Mask: Waves, Algorithm: Notched, Frequency: 15000
# Mask: Waves, Algorithm: Notched, Frequency: 16000
# Mask: Waves, Algorithm: Notched, Frequency: 17000
# Lake93.5064935064935%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Lake, Algorithm: Notched, Frequency: 20
# Mask: Lake, Algorithm: Notched, Frequency: 40
# Mask: Lake, Algorithm: Notched, Frequency: 60
# Mask: Lake, Algorithm: Notched, Frequency: 80
# Mask: Lake, Algorithm: Notched, Frequency: 100
# Mask: Lake, Algorithm: Notched, Frequency: 120
# Mask: Lake, Algorithm: Notched, Frequency: 140
# Mask: Lake, Algorithm: Notched, Frequency: 160
# Mask: Lake, Algorithm: Notched, Frequency: 180
# Mask: Lake, Algorithm: Notched, Frequency: 200
# Mask: Lake, Algorithm: Notched, Frequency: 300
# Mask: Lake, Algorithm: Notched, Frequency: 400
# Mask: Lake, Algorithm: Notched, Frequency: 500
# Mask: Lake, Algorithm: Notched, Frequency: 600
# Mask: Lake, Algorithm: Notched, Frequency: 700
# Mask: Lake, Algorithm: Notched, Frequency: 800
# Mask: Lake, Algorithm: Notched, Frequency: 900
# Mask: Lake, Algorithm: Notched, Frequency: 1000
# Mask: Lake, Algorithm: Notched, Frequency: 2000
# Mask: Lake, Algorithm: Notched, Frequency: 3000
# Mask: Lake, Algorithm: Notched, Frequency: 4000
# Mask: Lake, Algorithm: Notched, Frequency: 5000
# Mask: Lake, Algorithm: Notched, Frequency: 6000
# Mask: Lake, Algorithm: Notched, Frequency: 7000
# Mask: Lake, Algorithm: Notched, Frequency: 8000
# Mask: Lake, Algorithm: Notched, Frequency: 9000
# Mask: Lake, Algorithm: Notched, Frequency: 10000
# Mask: Lake, Algorithm: Notched, Frequency: 11000
# Mask: Lake, Algorithm: Notched, Frequency: 12000
# Mask: Lake, Algorithm: Notched, Frequency: 13000
# Mask: Lake, Algorithm: Notched, Frequency: 14000
# Mask: Lake, Algorithm: Notched, Frequency: 15000
# Mask: Lake, Algorithm: Notched, Frequency: 16000
# Mask: Lake, Algorithm: Notched, Frequency: 17000
# Car94.8051948051948%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Car, Algorithm: Notched, Frequency: 20
# Mask: Car, Algorithm: Notched, Frequency: 40
# Mask: Car, Algorithm: Notched, Frequency: 60
# Mask: Car, Algorithm: Notched, Frequency: 80
# Mask: Car, Algorithm: Notched, Frequency: 100
# Mask: Car, Algorithm: Notched, Frequency: 120
# Mask: Car, Algorithm: Notched, Frequency: 140
# Mask: Car, Algorithm: Notched, Frequency: 160
# Mask: Car, Algorithm: Notched, Frequency: 180
# Mask: Car, Algorithm: Notched, Frequency: 200
# Mask: Car, Algorithm: Notched, Frequency: 300
# Mask: Car, Algorithm: Notched, Frequency: 400
# Mask: Car, Algorithm: Notched, Frequency: 500
# Mask: Car, Algorithm: Notched, Frequency: 600
# Mask: Car, Algorithm: Notched, Frequency: 700
# Mask: Car, Algorithm: Notched, Frequency: 800
# Mask: Car, Algorithm: Notched, Frequency: 900
# Mask: Car, Algorithm: Notched, Frequency: 1000
# Mask: Car, Algorithm: Notched, Frequency: 2000
# Mask: Car, Algorithm: Notched, Frequency: 3000
# Mask: Car, Algorithm: Notched, Frequency: 4000
# Mask: Car, Algorithm: Notched, Frequency: 5000
# Mask: Car, Algorithm: Notched, Frequency: 6000
# Mask: Car, Algorithm: Notched, Frequency: 7000
# Mask: Car, Algorithm: Notched, Frequency: 8000
# Mask: Car, Algorithm: Notched, Frequency: 9000
# Mask: Car, Algorithm: Notched, Frequency: 10000
# Mask: Car, Algorithm: Notched, Frequency: 11000
# Mask: Car, Algorithm: Notched, Frequency: 12000
# Mask: Car, Algorithm: Notched, Frequency: 13000
# Mask: Car, Algorithm: Notched, Frequency: 14000
# Mask: Car, Algorithm: Notched, Frequency: 15000
# Mask: Car, Algorithm: Notched, Frequency: 16000
# Mask: Car, Algorithm: Notched, Frequency: 17000
# Heatfan96.1038961038961%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Heatfan, Algorithm: Notched, Frequency: 20
# Mask: Heatfan, Algorithm: Notched, Frequency: 40
# Mask: Heatfan, Algorithm: Notched, Frequency: 60
# Mask: Heatfan, Algorithm: Notched, Frequency: 80
# Mask: Heatfan, Algorithm: Notched, Frequency: 100
# Mask: Heatfan, Algorithm: Notched, Frequency: 120
# Mask: Heatfan, Algorithm: Notched, Frequency: 140
# Mask: Heatfan, Algorithm: Notched, Frequency: 160
# Mask: Heatfan, Algorithm: Notched, Frequency: 180
# Mask: Heatfan, Algorithm: Notched, Frequency: 200
# Mask: Heatfan, Algorithm: Notched, Frequency: 300
# Mask: Heatfan, Algorithm: Notched, Frequency: 400
# Mask: Heatfan, Algorithm: Notched, Frequency: 500
# Mask: Heatfan, Algorithm: Notched, Frequency: 600
# Mask: Heatfan, Algorithm: Notched, Frequency: 700
# Mask: Heatfan, Algorithm: Notched, Frequency: 800
# Mask: Heatfan, Algorithm: Notched, Frequency: 900
# Mask: Heatfan, Algorithm: Notched, Frequency: 1000
# Mask: Heatfan, Algorithm: Notched, Frequency: 2000
# Mask: Heatfan, Algorithm: Notched, Frequency: 3000
# Mask: Heatfan, Algorithm: Notched, Frequency: 4000
# Mask: Heatfan, Algorithm: Notched, Frequency: 5000
# Mask: Heatfan, Algorithm: Notched, Frequency: 6000
# Mask: Heatfan, Algorithm: Notched, Frequency: 7000
# Mask: Heatfan, Algorithm: Notched, Frequency: 8000
# Mask: Heatfan, Algorithm: Notched, Frequency: 9000
# Mask: Heatfan, Algorithm: Notched, Frequency: 10000
# Mask: Heatfan, Algorithm: Notched, Frequency: 11000
# Mask: Heatfan, Algorithm: Notched, Frequency: 12000
# Mask: Heatfan, Algorithm: Notched, Frequency: 13000
# Mask: Heatfan, Algorithm: Notched, Frequency: 14000
# Mask: Heatfan, Algorithm: Notched, Frequency: 15000
# Mask: Heatfan, Algorithm: Notched, Frequency: 16000
# Mask: Heatfan, Algorithm: Notched, Frequency: 17000
# Patagonia97.40259740259741%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Patagonia, Algorithm: Notched, Frequency: 20
# Mask: Patagonia, Algorithm: Notched, Frequency: 40
# Mask: Patagonia, Algorithm: Notched, Frequency: 60
# Mask: Patagonia, Algorithm: Notched, Frequency: 80
# Mask: Patagonia, Algorithm: Notched, Frequency: 100
# Mask: Patagonia, Algorithm: Notched, Frequency: 120
# Mask: Patagonia, Algorithm: Notched, Frequency: 140
# Mask: Patagonia, Algorithm: Notched, Frequency: 160
# Mask: Patagonia, Algorithm: Notched, Frequency: 180
# Mask: Patagonia, Algorithm: Notched, Frequency: 200
# Mask: Patagonia, Algorithm: Notched, Frequency: 300
# Mask: Patagonia, Algorithm: Notched, Frequency: 400
# Mask: Patagonia, Algorithm: Notched, Frequency: 500
# Mask: Patagonia, Algorithm: Notched, Frequency: 600
# Mask: Patagonia, Algorithm: Notched, Frequency: 700
# Mask: Patagonia, Algorithm: Notched, Frequency: 800
# Mask: Patagonia, Algorithm: Notched, Frequency: 900
# Mask: Patagonia, Algorithm: Notched, Frequency: 1000
# Mask: Patagonia, Algorithm: Notched, Frequency: 2000
# Mask: Patagonia, Algorithm: Notched, Frequency: 3000
# Mask: Patagonia, Algorithm: Notched, Frequency: 4000
# Mask: Patagonia, Algorithm: Notched, Frequency: 5000
# Mask: Patagonia, Algorithm: Notched, Frequency: 6000
# Mask: Patagonia, Algorithm: Notched, Frequency: 7000
# Mask: Patagonia, Algorithm: Notched, Frequency: 8000
# Mask: Patagonia, Algorithm: Notched, Frequency: 9000
# Mask: Patagonia, Algorithm: Notched, Frequency: 10000
# Mask: Patagonia, Algorithm: Notched, Frequency: 11000
# Mask: Patagonia, Algorithm: Notched, Frequency: 12000
# Mask: Patagonia, Algorithm: Notched, Frequency: 13000
# Mask: Patagonia, Algorithm: Notched, Frequency: 14000
# Mask: Patagonia, Algorithm: Notched, Frequency: 15000
# Mask: Patagonia, Algorithm: Notched, Frequency: 16000
# Mask: Patagonia, Algorithm: Notched, Frequency: 17000
# Net98.7012987012987%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Net, Algorithm: Notched, Frequency: 20
# Mask: Net, Algorithm: Notched, Frequency: 40
# Mask: Net, Algorithm: Notched, Frequency: 60
# Mask: Net, Algorithm: Notched, Frequency: 80
# Mask: Net, Algorithm: Notched, Frequency: 100
# Mask: Net, Algorithm: Notched, Frequency: 120
# Mask: Net, Algorithm: Notched, Frequency: 140
# Mask: Net, Algorithm: Notched, Frequency: 160
# Mask: Net, Algorithm: Notched, Frequency: 180
# Mask: Net, Algorithm: Notched, Frequency: 200
# Mask: Net, Algorithm: Notched, Frequency: 300
# Mask: Net, Algorithm: Notched, Frequency: 400
# Mask: Net, Algorithm: Notched, Frequency: 500
# Mask: Net, Algorithm: Notched, Frequency: 600
# Mask: Net, Algorithm: Notched, Frequency: 700
# Mask: Net, Algorithm: Notched, Frequency: 800
# Mask: Net, Algorithm: Notched, Frequency: 900
# Mask: Net, Algorithm: Notched, Frequency: 1000
# Mask: Net, Algorithm: Notched, Frequency: 2000
# Mask: Net, Algorithm: Notched, Frequency: 3000
# Mask: Net, Algorithm: Notched, Frequency: 4000
# Mask: Net, Algorithm: Notched, Frequency: 5000
# Mask: Net, Algorithm: Notched, Frequency: 6000
# Mask: Net, Algorithm: Notched, Frequency: 7000
# Mask: Net, Algorithm: Notched, Frequency: 8000
# Mask: Net, Algorithm: Notched, Frequency: 9000
# Mask: Net, Algorithm: Notched, Frequency: 10000
# Mask: Net, Algorithm: Notched, Frequency: 11000
# Mask: Net, Algorithm: Notched, Frequency: 12000
# Mask: Net, Algorithm: Notched, Frequency: 13000
# Mask: Net, Algorithm: Notched, Frequency: 14000
# Mask: Net, Algorithm: Notched, Frequency: 15000
# Mask: Net, Algorithm: Notched, Frequency: 16000
# Mask: Net, Algorithm: Notched, Frequency: 17000
# Ice100.0%
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:39: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# /Users/georgeleidig/Development/misc/audio_processing/audio_process_functions.py:146: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = read(filepath)
# Mask: Ice, Algorithm: Notched, Frequency: 20
# Mask: Ice, Algorithm: Notched, Frequency: 40
# Mask: Ice, Algorithm: Notched, Frequency: 60
# Mask: Ice, Algorithm: Notched, Frequency: 80
# Mask: Ice, Algorithm: Notched, Frequency: 100
# Mask: Ice, Algorithm: Notched, Frequency: 120
# Mask: Ice, Algorithm: Notched, Frequency: 140
# Mask: Ice, Algorithm: Notched, Frequency: 160
# Mask: Ice, Algorithm: Notched, Frequency: 180
# Mask: Ice, Algorithm: Notched, Frequency: 200
# Mask: Ice, Algorithm: Notched, Frequency: 300
# Mask: Ice, Algorithm: Notched, Frequency: 400
# Mask: Ice, Algorithm: Notched, Frequency: 500
# Mask: Ice, Algorithm: Notched, Frequency: 600
# Mask: Ice, Algorithm: Notched, Frequency: 700
# Mask: Ice, Algorithm: Notched, Frequency: 800
# Mask: Ice, Algorithm: Notched, Frequency: 900
# Mask: Ice, Algorithm: Notched, Frequency: 1000
# Mask: Ice, Algorithm: Notched, Frequency: 2000
# Mask: Ice, Algorithm: Notched, Frequency: 3000
# Mask: Ice, Algorithm: Notched, Frequency: 4000
# Mask: Ice, Algorithm: Notched, Frequency: 5000
# Mask: Ice, Algorithm: Notched, Frequency: 6000
# Mask: Ice, Algorithm: Notched, Frequency: 7000
# Mask: Ice, Algorithm: Notched, Frequency: 8000
# Mask: Ice, Algorithm: Notched, Frequency: 9000
# Mask: Ice, Algorithm: Notched, Frequency: 10000
# Mask: Ice, Algorithm: Notched, Frequency: 11000
# Mask: Ice, Algorithm: Notched, Frequency: 12000
# Mask: Ice, Algorithm: Notched, Frequency: 13000
# Mask: Ice, Algorithm: Notched, Frequency: 14000
# Mask: Ice, Algorithm: Notched, Frequency: 15000
# Mask: Ice, Algorithm: Notched, Frequency: 16000
# Mask: Ice, Algorithm: Notched, Frequency: 17000
